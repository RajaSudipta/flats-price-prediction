# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/flats_feature_engg.csv')

# %%
df.head()
# Out:
#                   society  price      sector  price_per_sqft    area  \
# 0  maa bhagwati residency   0.45    sector 7          5000.0   900.0
# 1            apna enclave   0.50    sector 3          7692.0   650.0
# 2  tulsiani easy in homes   0.40  sohna road          6722.0   595.0
# 3     smart world orchard   1.47   sector 61         12250.0  1200.0
# 4        parkwood westend   0.70   sector 92          5204.0  1345.0
#
#                              areaWithType  bedRoom  bathroom balcony  \
# 0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
#    extra_rooms  floorNum facing       agePossession  super_built_up_area  \
# ...

# %%
df.shape
# Out:
# (2872, 18)

# %%
df.columns
# Out:
# Index(['society', 'price', 'sector', 'price_per_sqft', 'area', 'areaWithType',
#        'bedRoom', 'bathroom', 'balcony', 'extra_rooms', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2872 entries, 0 to 2871
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   society              2872 non-null   object
#  1   price                2871 non-null   float64
#  2   sector               2872 non-null   object
#  3   price_per_sqft       2871 non-null   float64
#  4   area                 2871 non-null   float64
#  5   areaWithType         2872 non-null   object
#  6   bedRoom              2872 non-null   int64
#  7   bathroom             2872 non-null   int64
#  8   balcony              2872 non-null   object
#  9   extra_rooms          2872 non-null   int64
#  10  floorNum             2872 non-null   int64
#  11  facing               2058 non-null   object
#  12  agePossession        2872 non-null   object
#  13  super_built_up_area  1894 non-null   float64
#  14  built_up_area        901 non-null    float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df[df.duplicated()]
# Out:
#                            society  price      sector  price_per_sqft    area  \
# 2565  krisumi waterfall residences   2.30  sector 36a         15551.0  1479.0
# 2571           smart world orchard   2.41   sector 61         14785.0  1630.0
# 2572    central park flower valley   2.50   sector 33         13270.0  1884.0
# 2577    central park flower valley   1.40   sector 33         21538.0   650.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2565                  Built Up area: 1479 (137.4 sq.m.)        2         2
# 2571  Built Up area: 1630 (151.43 sq.m.)Carpet area:...        3         3
# 2572                   Carpet area: 1884 (175.03 sq.m.)        3         3
# 2577               Super Built up area 650(60.39 sq.m.)        3         3
#
#      balcony  extra_rooms  floorNum facing       agePossession  \
# 2565       2            0        23    NaN           Undefined
# 2571       3            0         2   East        New Property
# ...

# %%
df.drop_duplicates(inplace=True, keep='first')

# %%
df.shape
# Out:
# (2868, 18)

# %%
df.head()
# Out:
#                   society  price      sector  price_per_sqft    area  \
# 0  maa bhagwati residency   0.45    sector 7          5000.0   900.0
# 1            apna enclave   0.50    sector 3          7692.0   650.0
# 2  tulsiani easy in homes   0.40  sohna road          6722.0   595.0
# 3     smart world orchard   1.47   sector 61         12250.0  1200.0
# 4        parkwood westend   0.70   sector 92          5204.0  1345.0
#
#                              areaWithType  bedRoom  bathroom balcony  \
# 0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
#    extra_rooms  floorNum facing       agePossession  super_built_up_area  \
# ...

# %% [markdown]
# 1. Society

# %%
df["society"].value_counts().shape
# Out:
# (599,)

# %%
df["society"].value_counts().sort_index
# Out:
# <bound method Series.sort_index of society
# tulip violet                            75
# ss the leaf                             73
# shapoorji pallonji joyville gurugram    42
# dlf new town heights                    38
# shree vardhman victoria                 34
#                                         ..
# saroop garden                            1
# m3m the tree of life                     1
# bajrang apartments                       1
# elan mercado                             1
# sanskriti apartment                      1
# Name: count, Length: 599, dtype: int64>

# %%
df['society'].value_counts(normalize=True).cumsum().head(65)
# Out:
# society
# tulip violet                            0.026151
# ss the leaf                             0.051604
# shapoorji pallonji joyville gurugram    0.066248
# dlf new town heights                    0.079498
# shree vardhman victoria                 0.091353
#                                           ...
# ats kocoon                              0.487099
# puri emerald bay                        0.491632
# puri diplomatic greens                  0.496165
# ansal heights 86                        0.500697
# ramsons kshitij                         0.505230
# Name: proportion, Length: 65, dtype: float64

# %% [markdown]
# Comment: Total 599 societies. But Top 65 societies contain 50% of data. Many flats are from those societies only

# %%
society_counts = df['society'].value_counts()

# Frequency distribution for societies
frequency_bins = {
    "Very High (>100)": (society_counts > 100).sum(),
    "High (50-100)": ((society_counts >= 50) & (society_counts <= 100)).sum(),
    "Average (10-49)": ((society_counts >= 10) & (society_counts < 50)).sum(),
    "Low (2-9)": ((society_counts > 1) & (society_counts < 10)).sum(),
    "Very Low (1)": (society_counts == 1).sum()
}
frequency_bins
# Out:
# {'Very High (>100)': np.int64(0),
#  'High (50-100)': np.int64(2),
#  'Average (10-49)': np.int64(84),
#  'Low (2-9)': np.int64(234),
#  'Very Low (1)': np.int64(279)}

# %% [markdown]
# Comment: Maximum societies have occurred 1-9 times.

# %%
df['society'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='society'>

# %% [markdown]
# Comments: These societies have max frequencies in data

# %%
df['society'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Observations<br>
# 1. There are 599 societies.<br>
# 2. The top 65 societies have 50 percent of the preperties and the rest 50 percent of the properties come under the remaining 535 societies<br>
# 3. High (50-100): 2 societies have between 50 to 100 listings.<br>
# 4. Average (10-49): 84 societies fall in this range with 10 to 49 listings each.<br>
# 5. Low (2-9): 234 societies have between 2 to 9 listings.<br>
# 6. Very Low (1): A significant number, 279 societies, have only 1 listing.<br>

# %% [markdown]
# 2. Sector

# %%
df['sector'].value_counts().shape
# Out:
# (147,)

# %%
df['sector'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='sector'>

# %%
# Frequency distribution for sectors
sector_counts = df['sector'].value_counts()

sector_frequency_bins = {
    "Very High (>100)": (sector_counts > 100).sum(),
    "High (50-100)": ((sector_counts >= 50) & (sector_counts <= 100)).sum(),
    "Average (10-49)": ((sector_counts >= 10) & (sector_counts < 50)).sum(),
    "Low (2-9)": ((sector_counts > 1) & (sector_counts < 10)).sum(),
    "Very Low (1)": (sector_counts == 1).sum()
}

sector_frequency_bins
# Out:
# {'Very High (>100)': np.int64(3),
#  'High (50-100)': np.int64(18),
#  'Average (10-49)': np.int64(45),
#  'Low (2-9)': np.int64(43),
#  'Very Low (1)': np.int64(38)}

# %% [markdown]
# Observations<br>
# 1. There are a total of 147 unique sectors in the dataset.<br>
# 2. Frequency distribution of sectors:<br>
# Very High (>100): 3 sectors have more than 100 listings.<br>
# High (50-100): 18 sectors have between 50 to 100 listings.<br>
# Average (10-49): A majority, 45 sectors, fall in this range with 10 to 49 listings each.<br>
# Low (2-9): 43 sectors have between 2 to 9 listings.<br>
# Very Low (1): 38 sectors with only 1 listing.

# %% [markdown]
# 3. Price

# %%
df['price'].isnull().sum()
# Out:
# np.int64(1)

# %% [markdown]
# 3. Price

# %%
df['price'].describe()
# Out:
# count    2867.000000
# mean        1.708947
# std         1.387263
# min         0.160000
# 25%         0.900000
# 50%         1.380000
# 75%         2.045000
# max        15.000000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'], kde=True, bins=50)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(x=df['price'], color='lightgreen')
plt.grid()

# %% [markdown]
# Descriptive Statistics:<br>
# Count: There are 2867 non-missing price entries.<br>
# Mean Price: The average price is approximately 1.7 crores.<br>
# Median Price: The median (or 50th percentile) price is 1.38 crores.<br>
# Standard Deviation: The prices have a standard deviation of 1.38, indicating variability in the prices.<br>
# Range: Prices range from a minimum of 0.16 crores to a maximum of 15 crores.<br>
# IQR: The interquartile range (difference between 75th and 25th percentile) is from 0.90 crores to 2.04 crores.<br>
#
# Visualizations:<br>
# Distribution: The histogram indicates that most properties are priced in the lower range (below 5 crores), with a few properties going beyond 10 crores.<br>
# Box Plot: The box plot showcases the spread of the data and potential outliers. Properties priced above approximately 10 crores might be considered outliers as they lie beyond the upper whisker of the box plot.<br>
# Missing Values: There are 1 missing values in the price column.<br>

# %%
# Skewness and Kurtosis
skewness = df['price'].skew()
kurtosis = df['price'].kurt()

print(skewness,kurtosis)
# Out:
# 2.892687006000398 13.803642834002549

# %% [markdown]
# Skewness: The price distribution has a skewness of approximately 2.89, indicating a positive skew. This means that the distribution tail is skewed to the right, which aligns with our observation from the histogram where most properties have prices on the lower end with a few high-priced properties.<br>
#
# Kurtosis: The kurtosis value is approximately 13.80. A kurtosis value greater than 3 indicates a distribution with heavier tails and more outliers compared to a normal distribution.

# %%
# Quantile Analysis
quantiles = df['price'].quantile([0.01, 0.05, 0.95, 0.99])
quantiles
# Out:
# 0.01    0.24
# 0.05    0.35
# 0.95    4.25
# 0.99    7.00
# Name: price, dtype: float64

# %% [markdown]
# Quantile Analysis:<br>
#
# 1% Quantile: Only 1% of properties are priced below 0.24 crores.<br>
# 5% Quantile: 5% of properties are priced below 0.35 crores.<br>
# 95% Quantile: 95% of properties are priced below 4.25 crores.<br>
# 99% Quantile: 99% of properties are priced below 7.00 crores, indicating that very few properties are priced above this value.<br>

# %%
# Identify potential outliers using IQR method
Q1 = df['price'].describe()['25%']
Q3 = df['price'].describe()['75%']
IQR = Q3 - Q1

IQR
# Out:
# np.float64(1.145)

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound, upper_bound)
# Out:
# -0.8175 3.7625

# %%
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
outliers.shape
# Out:
# (190, 18)

# %%
outliers['price'].describe()
# Out:
# count    190.000000
# mean       5.654947
# std        1.918374
# min        3.780000
# 25%        4.250000
# 50%        5.000000
# 75%        6.237500
# max       15.000000
# Name: price, dtype: float64

# %% [markdown]
# Outliers Analysis (using IQR method):<br>
#
# Based on the IQR method, there are 190 properties considered as outliers.<br>
# These outliers have an average price of approximately 5.65 crores.<br>
# The range for these outliers is from 3.78 crores to 15 crores.<br>

# %%
# price binning
bins = [0, 1, 2, 3, 5, 10, 20, 50]
bin_labels = ["0-1", "1-2", "2-3", "3-5", "5-10", "10-20", "20-50"]
pd.cut(df['price'], bins=bins, labels=bin_labels, right=False).value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# The majority of properties are priced in the "0-3 crores" ranges.<br>
# There's a significant drop in the number of properties priced above "10 crores"<br>

# %%
# ecdf plot
ecdf = df['price'].value_counts().sort_index().cumsum() / len(df['price'])
plt.plot(ecdf.index, ecdf, marker='.', linestyle='none')
plt.grid()

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.histplot(df['price'], kde=True, bins=50, color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.histplot(np.log1p(df['price']), kde=True, bins=50, color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Comment: log transformation removes skewness and tries to create normal distribution<br>
# np.log1p(x): This function computes the natural logarithm of 1+x. It's designed to provide more accurate results for values of x that are very close to zero.<br>
#
# Using np.log1p helps in transforming the price column while ensuring that any value (including zero, if present) is handled appropriately. When we need to reverse the transformation, we can use np.expm1 which computes e^x-1<br>

# %%
skewness = np.log1p(df['price']).skew()
kurtosis = np.log1p(df['price']).kurt()

print(skewness,kurtosis)
# Out:
# 0.7790073550604708 1.0443052936629624

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.boxplot(df['price'], color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.boxplot(np.log1p(df['price']), color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Price per sqft

# %%
df['price_per_sqft'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['price_per_sqft'].describe()
# Out:
# count      2867.000000
# mean       9322.197419
# std        5583.699955
# min           4.000000
# 25%        6491.000000
# 50%        8333.000000
# 75%       11058.000000
# max      200000.000000
# Name: price_per_sqft, dtype: float64

# %%
sns.histplot(df['price_per_sqft'], bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %% [markdown]
# Most properties have a price_per_sqft ranging between approximately ₹0 and ₹30,000. There is a significant concentration in the lower range, with a few properties having exceptionally high price_per_sqft.

# %%
sns.boxplot(df['price_per_sqft'], color='lightgreen')
# Out:
# <Axes: ylabel='price_per_sqft'>

# %% [markdown]
# The box plot clearly shows several outliers, especially on the higher side. The interquartile range (IQR) is relatively compact, but there are many data points beyond the "whiskers" of the box plot, indicating potential outliers<br>
#
# Observations<br>
# 1. Potential Outliers<br>
# 2. Right Skewed<br>
# 3. 17 missing values<br>

# %% [markdown]
# 5. Bedroom

# %%
df['bathroom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bathroom'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bathroom'>

# %%
df['bathroom'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# 6. Balcony

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['balcony'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='balcony'>

# %%
df['balcony'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# 7. Floornum

# %%
df['floorNum'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['floorNum'].describe()
# Out:
# count    2868.000000
# mean        7.934449
# std         6.185530
# min         0.000000
# 25%         3.000000
# 50%         7.000000
# 75%        11.000000
# max        45.000000
# Name: floorNum, dtype: float64

# %%
df['floorNum'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='floorNum'>

# %%
sns.boxplot(df['floorNum'], color='lightgreen')
# Out:
# <Axes: ylabel='floorNum'>

# %% [markdown]
# Comment: <br>
# The majority of the properties lie between the ground floor (0) and the 25th floor.<br>
# Floors 1 to 4 are particularly common, with the 2nd floor being the most frequent.<br>
# There are a few properties located at higher floors, but their frequency is much lower.<br>
# The box plot reveals that the majority of the properties are concentrated around the lower floors. The interquartile range (IQR) lies between approximately the 2nd and 10th floors.<br>
# Data points beyond the "whiskers" of the box plot, especially on the higher side, indicate potential outliers.<br>

# %% [markdown]
# 8. Facing

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(811)

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# /tmp/ipykernel_5965/2381597952.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            811
# North-East    488
# East          471
# North         290
# South         201
# West          178
# North-West    155
# South-East    143
# South-West    131
# Name: count, dtype: int64

# %% [markdown]
# 9. agePossession

# %%
df['agePossession'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1448
# New Property           496
# Moderately Old         348
# Under Construction     257
# Undefined              189
# Old Property           130
# Name: count, dtype: int64

# %% [markdown]
# 10. Areas

# %%
# super built up area
df['super_built_up_area'].isnull().sum()
# Out:
# np.int64(975)

# %%
df['super_built_up_area'].describe()
# Out:
# count     1893.000000
# mean      1920.915240
# std        765.408479
# min         89.000000
# 25%       1465.000000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
sns.histplot(df['super_built_up_area'].dropna(), bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='super_built_up_area', ylabel='Count'>

# %%
sns.boxplot(df['super_built_up_area'].dropna(), color='lightgreen')
# Out:
# <Axes: ylabel='super_built_up_area'>

# %% [markdown]
# Comment:<br>
# 1. Most properties have a super built-up area ranging between approximately 1,000 sq.ft and 2,500 sq.ft.<br>
# 2. There are a few properties with a significantly larger area, leading to a right-skewed distribution.<br>
# 3. The interquartile range (IQR) lies between roughly 1,480 sq.ft and 2,215 sq.ft, indicating that the middle 50% of the properties fall within this range.<br>
# 4. There are several data points beyond the upper "whisker" of the box plot, indicating potential outliers. These are properties with an unusually large super built-up area.<br>

# %%
# built up area
df['built_up_area'].isnull().sum()
# Out:
# np.int64(1969)

# %%
df['built_up_area'].describe()
# Out:
# count       899.000000
# mean       2531.386830
# std       24539.182763
# min          97.000000
# 25%        1275.765000
# 50%        1622.000000
# 75%        2000.000000
# max      737147.000000
# Name: built_up_area, dtype: float64

# %%
sns.histplot(df['built_up_area'].dropna(), bins=50, color='skyblue', kde=False)
# Out:
# <Axes: xlabel='built_up_area', ylabel='Count'>

# %%
sns.boxplot(df['built_up_area'].dropna(), color='lightgreen')
# Out:
# <Axes: ylabel='built_up_area'>

# %% [markdown]
# Most properties have a built-up area ranging roughly between 500 sq.ft and 3,500 sq.ft.<br>
# There are very few properties with a much larger built-up area, leading to a highly right-skewed distribution.<br>
# The box plot confirms the presence of significant outliers on the higher side. The data's interquartile range (IQR) is relatively compact, but the "whiskers" of the box plot are stretched due to the outliers.<br>
# The presence of extreme values, especially on the higher side, suggests that there may be outliers or data errors. This could also be due to some properties being exceptionally large, like a commercial complex or an entire building being listed.<br>

# %%
# carpet area
df['carpet_area'].isnull().sum()
# Out:
# np.int64(1123)

# %%
df['carpet_area'].describe()
# Out:
# count      1745.000000
# mean       2599.110223
# std       23605.913028
# min          66.000000
# 25%         900.000000
# 50%        1304.000000
# 75%        1775.000000
# max      607936.000000
# Name: carpet_area, dtype: float64

# %%
sns.histplot(df['carpet_area'].dropna(), bins=50, color='skyblue', kde=False)
# Out:
# <Axes: xlabel='carpet_area', ylabel='Count'>

# %%
sns.boxplot(df['carpet_area'].dropna(), color='lightgreen')
# Out:
# <Axes: ylabel='carpet_area'>

# %% [markdown]
# Comment: outliers present here too

# %% [markdown]
# 11. additional rooms

# %%
df["extra_rooms"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 12. furnishing_type

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 0    1916
# 2     804
# 1     148
# Name: count, dtype: int64

# %%
df['furnishing_type'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 13. Luxury Score

# %%
df['luxury_score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['luxury_score'].describe()
# Out:
# count    2868.000000
# mean       77.910042
# std        52.224625
# min         0.000000
# 25%        42.000000
# 50%        66.000000
# 75%       117.000000
# max       174.000000
# Name: luxury_score, dtype: float64

# %%
sns.histplot(df['luxury_score'], bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='luxury_score', ylabel='Count'>

# %%
sns.boxplot(df['luxury_score'], color='lightgreen')
# Out:
# <Axes: ylabel='luxury_score'>

# %% [markdown]
# Comments:<br>
# The luxury score distribution has multiple peaks, suggesting a multi-modal distribution. There's a significant number of properties with lower luxury scores (around 0-50), and another peak is observed around the 110-130 range.<br>
#
# The box plot reveals that the majority of the properties have luxury scores between approximately 30 and 110. The interquartile range (IQR) lies between these values.<br>

# %%
df.head()
# Out:
#                   society  price      sector  price_per_sqft    area  \
# 0  maa bhagwati residency   0.45    sector 7          5000.0   900.0
# 1            apna enclave   0.50    sector 3          7692.0   650.0
# 2  tulsiani easy in homes   0.40  sohna road          6722.0   595.0
# 3     smart world orchard   1.47   sector 61         12250.0  1200.0
# 4        parkwood westend   0.70   sector 92          5204.0  1345.0
#
#                              areaWithType  bedRoom  bathroom balcony  \
# 0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
#    extra_rooms  floorNum facing       agePossession  super_built_up_area  \
# ...
